# %%
import pandas as pd
import numpy as np

# %%
# %%html
# <style>
#     table.dataframe th,table.dataframe td{
#         border:1px solid black;
#         background-color:white;
#     }
# </style>
# Out:
# <style>
#     table.dataframe th,table.dataframe td{
#         border:1px solid black;
#         background-color:white;
#     }
# </style>

# %%
df = pd.read_csv('4. Cars Data1.csv')

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#   EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  \
# 0        3.5        6.0       265.0      17.0         23.0  4451.0      106.0
# 1          2        4.0       200.0      24.0         31.0  2778.0      101.0
# 2        2.4        4.0       200.0      22.0         29.0  3230.0      105.0
# 3        3.2        6.0       270.0      20.0         28.0  3575.0      108.0
# 4        3.5        6.0       225.0      18.0         24.0  3880.0      115.0
#
#    Length
# 0   189.0
# 1   172.0
# 2   183.0
# 3   186.0
# 4   197.0

# %%
df.shape
# Out:
# (429, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    object
#  8   Cylinders    427 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    427 non-null    float64
#  14  Length       427 non-null    float64
# dtypes: float64(7), object(8)
# memory usage: 50.4+ KB

# %%
df.isnull().sum()
# Out:
# Make           1
# Model          1
# Type           1
# Origin         1
# DriveTrain     1
# MSRP           1
# Invoice        1
# EngineSize     1
# Cylinders      2
# Horsepower     1
# MPG_City       1
# MPG_Highway    1
# Weight         1
# Wheelbase      2
# Length         2
# dtype: int64

# %%
df['Cylinders'].fillna(value= np.mean,inplace=True)

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 427  Volvo                      V40  Wagon  Europe      Front  $26,135
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %%
df['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Chrysler         15
# Volkswagen       15
# Dodge            13
# Mitsubishi       13
# Jaguar           12
# Volvo            12
# Hyundai          12
# Mazda            11
# Lexus            11
# Pontiac          11
# Kia              11
# Subaru           11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Infiniti          8
# GMC               8
# Suzuki            8
# Cadillac          8
# Acura             7
# Saab              7
# Porsche           7
# Jeep              3
# Oldsmobile        3
# Land Rover        3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
df[(df['Origin']=='Asia') | (df['Origin']=='Europe')]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 427  Volvo                      V40  Wagon  Europe      Front  $26,135
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %%
df[~(df['Weight']>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 427  Volvo                      V40  Wagon  Europe      Front  $26,135
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 427  Volvo                      V40  Wagon  Europe      Front  $26,135
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %%
def fun(x):
    return x+3

# %%
df['MPG_City'] = df['MPG_City'].apply(fun)

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 427  Volvo                      V40  Wagon  Europe      Front  $26,135
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...
